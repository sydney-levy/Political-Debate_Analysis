# %% [markdown]
# # Generate Questions (using GPT 4-mini) based on Debate Dialogues for Democrats

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

import textwrap

import nltk
from nltk.sentiment.vader import SentimentIntensityAnalyzer
nltk.download('vader_lexicon')

from transformers import AutoTokenizer, AutoModelForSequenceClassification
from transformers import BertModel, BertTokenizer, AdamW
import torch
import os
from transformers import AutoTokenizer, AutoModelForCausalLM

from openai import OpenAI
from google.colab import userdata
# Out:
# [nltk_data] Downloading package vader_lexicon to /root/nltk_data...

# %% [markdown]
# # Generate Questions (using GPT 4-mini) based on Debate Dialogues for Democrats between 2016 and 2024

# %%
dem_2016 = pd.read_csv("2016_democrat_data.csv")

# %%
dem_2016
# Out:
#      actor                                           dialogue        date  \
# 0    Kaine  Elaine, thank you for being here tonight, and,...  2016-10-04
# 1    Kaine  Elaine, let me tell you why I trust Hillary Cl...  2016-10-04
# 2    Kaine  You both have said  you both have said Vladimi...  2016-10-04
# 3    Kaine  These guys have praised Vladimir Putin as a gr...  2016-10-04
# 4    Kaine      And paid few taxes and lost a billion a year.  2016-10-04
# ..     ...                                                ...         ...
# 627  BIDEN  Well, guess what? We got it – we got it down t...  2024-06-27
# 628  BIDEN  You know what that did? That reduced the feder...  2024-06-27
# 629  BIDEN  I'm going to make that available to every seni...  2024-06-27
# 630  BIDEN  We have – I'm going to make sure we have child...  2024-06-27
# 631  BIDEN  We're going to continue to fight to bring down...  2024-06-27
#
#         Party  word_count
# 0    Democrat         415
# 1    Democrat         248
# 2    Democrat          17
# 3    Democrat          13
# 4    Democrat          10
# ..        ...         ...
# 627  Democrat          39
# 628  Democrat          29
# 629  Democrat          28
# 630  Democrat          51
# 631  Democrat          15
#
# [632 rows x 5 columns]

# %%
# Sydneys's API key
api_key_me = userdata.get('MIT_NLP_OPEN_AI')
client = OpenAI(api_key=api_key_me)

def chatWithGPT(prompt):
    response = client.chat.completions.create(
        model="gpt-4o-mini",
        messages=[
            {"role": "system", "content": "You are a helpful assistant."},
            {"role": "user", "content": prompt}
        ]
    )

    return response.choices[0].message.content

# Define a function to categorize each response using GPT-4o-mini
def categorize_response(text):
    prompt = (f"Craft a question a debate moderator might ask that would naturally lead to the following response in a presidential debate. The question should be neutral, engaging, and directly related to the content of the provided response. Only provide the question, no explanation: {text}")
    # Call the GPT-4 o mini API
    return chatWithGPT(prompt)

# %%
# Set up a counter to track progress throughout the run
processed_count = 0

# Saving every 100 rows
for i in range(len(dem_2016)):
    dem_2016.at[i, 'gpt_4_mini_question'] = categorize_response(dem_2016.at[i, 'dialogue'])

    # Increment the counter
    processed_count += 1

    # Print progress update every 10 rows
    if processed_count % 100 == 0:
        print(f"Processed {processed_count}/{len(dem_2016)} rows")

    # Save progress every 100 rows
    if processed_count % 100 == 0:
        dem_2016.to_csv('dem_2016_questions.csv', index=False)
        print(f"Checkpoint: Saved progress at {processed_count} rows")

# Save final result after all rows are processed
dem_2016.to_csv('dem_2016_questions.csv', index=False)
print("Processing complete. Final CSV saved.")

result = dem_2016
# Out:
# Processed 100/632 rows
# Checkpoint: Saved progress at 100 rows
# Processed 200/632 rows
# Checkpoint: Saved progress at 200 rows
# Processed 300/632 rows
# Checkpoint: Saved progress at 300 rows
# Processed 400/632 rows
# Checkpoint: Saved progress at 400 rows
# Processed 500/632 rows
# Checkpoint: Saved progress at 500 rows
# Processed 600/632 rows
# Checkpoint: Saved progress at 600 rows
# Processing complete. Final CSV saved.

# %%
dem_2016.head(20)
# Out:
#     actor                                           dialogue        date  \
# 0   Kaine  Elaine, thank you for being here tonight, and,...  2016-10-04
# 1   Kaine  Elaine, let me tell you why I trust Hillary Cl...  2016-10-04
# 2   Kaine  You both have said  you both have said Vladimi...  2016-10-04
# 3   Kaine  These guys have praised Vladimir Putin as a gr...  2016-10-04
# 4   Kaine      And paid few taxes and lost a billion a year.  2016-10-04
# 5   Kaine  You are Donald Trumps apprentice. Let me talk ...  2016-10-04
# 6   Kaine  Now, I get to weigh in. Now, let me just say this  2016-10-04
# 7   Kaine  Governor Pence  Governor Pence doesnt think th...  2016-10-04
# 8   Kaine  Let me tell you this. When Hillary Clinton bec...  2016-10-04
# 9   Kaine  Do you know that we had 175,000 troops deploye...  2016-10-04
# 10  Kaine  Absolutely, without firing a shot. And instead...  2016-10-04
# 11  Kaine  Well, if you want to put more American troops ...  2016-10-04
# 12  Kaine  Governor, President Bush said we would leave I...  2016-10-04
# 13  Kaine  If Governor Pence wants to put more troops bac...  2016-10-04
# 14  Kaine  Elaine, on the economy, theres a fundamental c...  2016-10-04
# 15  Kaine  But its not the giveaway tax relief to the fol...  2016-10-04
# 16  Kaine  I am interested to hear whether hell defend hi...  2016-10-04
# 17  Kaine  How do you know that? You havent seen his tax ...  2016-10-04
# 18  Kaine  Donald Trump started this campaign in 2014 and...  2016-10-04
# 19  Kaine  Hes broken his first promise. Second, he stood...  2016-10-04
#
#        Party  word_count                                gpt_4_mini_question
# 0   Democrat         415  What experiences do you believe have best prep...
# 1   Democrat         248  "How do you evaluate the impact of a candidate...
# 2   Democrat          17  "How would you assess the leadership styles of...
# 3   Democrat          13  What is your stance on the recent comments mad...
# 4   Democrat          10  "In your view, how should we address the issue...
# 5   Democrat          10  "Can you describe how your experience working ...
# 6   Democrat          12  "Can you share your perspective on the key iss...
# 7   Democrat          22  Governor Pence, how do you assess the current ...
# 8   Democrat          23  Governor Pence, can you discuss how the leader...
# 9   Democrat         101  What specific actions do you believe the U.S. ...
# 10  Democrat          17  What is your stance on military engagement and...
# 11  Democrat          15  What is your stance on the current military pr...
# 12  Democrat          57  Governor, given the timeline for U.S. troop wi...
# 13  Democrat          12  "What is your stance on the potential deployme...
# 14  Democrat         414  What are the key differences between your econ...
# 15  Democrat          13  Many critics of recent tax reform efforts argu...
# 16  Democrat          18  What is your stance on transparency in politic...
# 17  Democrat          11  What evidence do you have to support your clai...
# 18  Democrat          25  What is your stance on transparency and accoun...
# 19  Democrat          11  What do you think about the current administra...

# %%
dem_2016['gpt_4_mini_question'] = dem_2016['gpt_4_mini_question'].str.replace('"', '')
dem_2016.head(20)
# Out:
#     actor                                           dialogue        date  \
# 0   Kaine  Elaine, thank you for being here tonight, and,...  2016-10-04
# 1   Kaine  Elaine, let me tell you why I trust Hillary Cl...  2016-10-04
# 2   Kaine  You both have said  you both have said Vladimi...  2016-10-04
# 3   Kaine  These guys have praised Vladimir Putin as a gr...  2016-10-04
# 4   Kaine      And paid few taxes and lost a billion a year.  2016-10-04
# 5   Kaine  You are Donald Trumps apprentice. Let me talk ...  2016-10-04
# 6   Kaine  Now, I get to weigh in. Now, let me just say this  2016-10-04
# 7   Kaine  Governor Pence  Governor Pence doesnt think th...  2016-10-04
# 8   Kaine  Let me tell you this. When Hillary Clinton bec...  2016-10-04
# 9   Kaine  Do you know that we had 175,000 troops deploye...  2016-10-04
# 10  Kaine  Absolutely, without firing a shot. And instead...  2016-10-04
# 11  Kaine  Well, if you want to put more American troops ...  2016-10-04
# 12  Kaine  Governor, President Bush said we would leave I...  2016-10-04
# 13  Kaine  If Governor Pence wants to put more troops bac...  2016-10-04
# 14  Kaine  Elaine, on the economy, theres a fundamental c...  2016-10-04
# 15  Kaine  But its not the giveaway tax relief to the fol...  2016-10-04
# 16  Kaine  I am interested to hear whether hell defend hi...  2016-10-04
# 17  Kaine  How do you know that? You havent seen his tax ...  2016-10-04
# 18  Kaine  Donald Trump started this campaign in 2014 and...  2016-10-04
# 19  Kaine  Hes broken his first promise. Second, he stood...  2016-10-04
#
#        Party  word_count                                gpt_4_mini_question
# 0   Democrat         415  What experiences do you believe have best prep...
# 1   Democrat         248  How do you evaluate the impact of a candidate'...
# 2   Democrat          17  How would you assess the leadership styles of ...
# 3   Democrat          13  What is your stance on the recent comments mad...
# 4   Democrat          10  In your view, how should we address the issue ...
# 5   Democrat          10  Can you describe how your experience working w...
# 6   Democrat          12  Can you share your perspective on the key issu...
# 7   Democrat          22  Governor Pence, how do you assess the current ...
# 8   Democrat          23  Governor Pence, can you discuss how the leader...
# 9   Democrat         101  What specific actions do you believe the U.S. ...
# 10  Democrat          17  What is your stance on military engagement and...
# 11  Democrat          15  What is your stance on the current military pr...
# 12  Democrat          57  Governor, given the timeline for U.S. troop wi...
# 13  Democrat          12  What is your stance on the potential deploymen...
# 14  Democrat         414  What are the key differences between your econ...
# 15  Democrat          13  Many critics of recent tax reform efforts argu...
# 16  Democrat          18  What is your stance on transparency in politic...
# 17  Democrat          11  What evidence do you have to support your clai...
# 18  Democrat          25  What is your stance on transparency and accoun...
# 19  Democrat          11  What do you think about the current administra...

# %%
dem_2016.to_csv('dem_2016_questions_clean.csv', index=False)

# %% [markdown]
# # Generate Questions (using GPT 4-mini) based on Debate Dialogues for Democrats between 2016 and 2024

# %%
dem_1976 = pd.read_csv("1976_democrat_data.csv").drop(columns=["Unnamed: 0"])
dem_1976.head()
# Out:
#      actor                                           dialogue        date  \
# 0  Ferraro  Well, let me first say that I wasnt born at th...  1984-10-11
# 1  Ferraro  I dont. Let me say that Im not a believer in p...  1984-10-11
# 2  Ferraro  I, I think what Im going to have to do is Im g...  1984-10-11
# 3  Ferraro  With reference to the busing vote that I cast ...  1984-10-11
# 4  Ferraro  I do not support the use of quotas. Both Mr. M...  1984-10-11
#
#       Party  word_count
# 0  Democrat         383
# 1  Democrat         132
# 2  Democrat         161
# 3  Democrat         395
# 4  Democrat         130

# %%
# Set up a counter to track progress throughout the run
processed_count = 0

# Saving every 100 rows
for i in range(len(dem_1976)):
    dem_1976.at[i, 'gpt_4_mini_question'] = categorize_response(dem_1976.at[i, 'dialogue'])

    # Increment the counter
    processed_count += 1

    # Print progress update every 10 rows
    if processed_count % 100 == 0:
        print(f"Processed {processed_count}/{len(dem_1976)} rows")

    # Save progress every 100 rows
    if processed_count % 100 == 0:
        dem_1976.to_csv('dem_1976_questions.csv', index=False)
        print(f"Checkpoint: Saved progress at {processed_count} rows")

# Save final result after all rows are processed
dem_1976.to_csv('dem_1976_questions.csv', index=False)
print("Processing complete. Final CSV saved.")

result = dem_1976
# Out:
# Processed 100/158 rows
# Checkpoint: Saved progress at 100 rows
# Processing complete. Final CSV saved.

# %%
dem_1976['gpt_4_mini_question'] = dem_1976['gpt_4_mini_question'].str.replace('"', '')
dem_1976.to_csv('dem_1976_questions_clean.csv')
